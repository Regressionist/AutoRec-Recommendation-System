# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
from sklearn.utils import shuffle
from torch.autograd import Variable

# %%
df=pd.read_csv('ratings.csv',names=['userID','movieID','rating','time'])
df.drop('time',axis=1,inplace=True)
users=[k for k,v in df['userID'].value_counts().iteritems() if v>2]
movies=[k for k,v in df['movieID'].value_counts().iteritems() if v>10]
df=df[(df['userID'].isin(users)) & (df['movieID'].isin(movies))]
#df=df.sample(frac=1).reset_index(drop=True)
df=df.pivot(index='userID',columns='movieID',values='rating')
df.reset_index(drop=True,inplace=True)
print ('Dataframe size: {}'.format(df.shape))
# Out:
# Dataframe size: (240447, 14277)

# %%
train_df=(df.loc[:220000-1])
print ('Train dataframe size: {}'.format(train_df.shape))
test_df=df.loc[230000:].reset_index(drop=True)
print ('Test dataframe size: {}'.format(test_df.shape))
val_df=df.loc[220000:230000-1].reset_index(drop=True)
print ('Validation dataframe size: {}'.format(val_df.shape))
# Out:
# Train dataframe size: (220000, 14277)
# Test dataframe size: (10447, 14277)
# Validation dataframe size: (10000, 14277)

# %%
class Autorec(nn.Module):
    def __init__(self, hidden_size_1, hidden_size_2, dropout, input_size):
        super(Autorec, self).__init__()
        self.input_size=input_size
        self.hidden_size_1=hidden_size_1
        self.hidden_size_2=hidden_size_2
        
        self.encoder_l1=nn.Linear(self.input_size, self.hidden_size_1)
        self.encoder_l2=nn.Linear(self.hidden_size_1, self.hidden_size_2)
        self.decoder_l1=nn.Linear(self.hidden_size_2, self.hidden_size_1)
        self.decoder_l2=nn.Linear(self.hidden_size_1, self.input_size)
        self.drop = nn.Dropout(dropout)
        #self.sigmoid=nn.LogSigmoid()
        
        
    def forward(self, input_ratings):
        #input_ratings=F.normalize(input_ratings)
        enc_out = F.relu(self.encoder_l2(F.relu(self.encoder_l1(input_ratings))))
        enc_out=self.drop(enc_out)
        dec_out = self.decoder_l2(F.relu(self.decoder_l1(enc_out)))
        return dec_out

# %%
def train_minibatch(input_ratings, autorec, optimizer,criterion,r):
    optimizer.zero_grad()
    input_ratings=input_ratings.type(torch.cuda.FloatTensor)
    mask=input_ratings!=0
    mask=mask.type(torch.cuda.FloatTensor)
    output_ratings=autorec(input_ratings)
    #loss=torch.mean(torch.sum((output_ratings-input_ratings)**2,-1)/torch.sum(mask,-1))
    loss1=criterion(input_ratings, output_ratings*mask)
    loss1.backward()
    optimizer.step()
    loss2=0
    if r==True:
        optimizer.zero_grad()
        input_ratings=Variable(output_ratings).detach()
        mask=input_ratings!=0
        mask=mask.type(torch.cuda.FloatTensor)
        output_ratings=autorec(input_ratings)
    #loss=torch.mean(torch.sum((output_ratings-input_ratings)**2,-1)/torch.sum(mask,-1))
        loss2=criterion(input_ratings, output_ratings*mask)
        loss2.backward()
        optimizer.step()
    return torch.sqrt(loss1+loss2)

# %%
def validation(input_ratings, autorec):
    with torch.no_grad():
        input_ratings=input_ratings.type(torch.cuda.FloatTensor)
        mask=input_ratings!=0
        mask=mask.type(torch.cuda.FloatTensor)
        output_ratings=autorec(input_ratings)*mask
        loss=0
        for i in range(output_ratings.size(0)):
            indices=torch.nonzero(mask[i])
            l=0
            for idx in indices:
                l+=(input_ratings[i][idx]-output_ratings[i][idx])**2
            loss+=l/indices.size(0)
        #loss=torch.mean(torch.sum((output_ratings-input_ratings)**2,-1)/torch.sum(mask,-1))
        return (torch.sqrt(loss/mask.size(0))).item()

# %%
autorec=Autorec(hidden_size_1=1024, hidden_size_2=512, dropout=0.5, input_size=train_df.shape[1])
optimizer=optim.Adam(autorec.parameters())
device=torch.device('cuda')
criterion=nn.MSELoss()
autorec=autorec.to(device)

# %%
#val_mask=val_df.copy()
#val_mask[~val_mask.isnull()] = 1  # not nan
#val_mask[val_mask.isnull()] = 0   # nan
val_df[val_df.isnull()] = 0   # nan

# %%
input_users_val=torch.from_numpy(val_df.values).to(device).detach()
#mask_val=torch.from_numpy(val_mask.values).to(device).detach()

# %%
checkpoint = torch.load('model_autorec_DRF.pth')
autorec.load_state_dict(checkpoint['autorec_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
vl=checkpoint['val_loss']
tl=checkpoint['training_loss']
autorec.eval()
# Out:
# Autorec(
#   (encoder_l1): Linear(in_features=14277, out_features=1024, bias=True)
#   (encoder_l2): Linear(in_features=1024, out_features=512, bias=True)
#   (decoder_l1): Linear(in_features=512, out_features=1024, bias=True)
#   (decoder_l2): Linear(in_features=1024, out_features=14277, bias=True)
#   (drop): Dropout(p=0.5)
# )

# %%
#num_batches=60
#val_benchmark=10
#vl=[]
#tl=[]
#counter=0

for batch in range(38,90):
    running_loss=0
    counter=0
    #train_df = shuffle(train_df)
    while counter <train_df.shape[0]:
        tdf=(train_df.loc[counter:counter+99].copy())
        #train_mask=tdf.copy()
        #train_mask[~train_mask.isnull()] = 1  # not nan
        #train_mask[train_mask.isnull()] = 0   # nan
        tdf[tdf.isnull()] = 0
        
        assert tdf.shape[0]==100
        input_users=Variable(torch.from_numpy(tdf.values)).to(device)
        #input_mask=torch.from_numpy(train_mask.values).to(device)
        if(batch<40):
            r=False
        elif batch==40:
            r=True
            val_benchmark=1
        loss=train_minibatch(input_users, autorec, optimizer,criterion,r)
        running_loss+=loss.item()
        tl.append(loss.item())
        
        if (counter+100)%44000==0:
            val_rmse=validation(input_users_val, autorec)
            vl.append(val_rmse)
            print ('Batch: {} | Step: {}/{} | Training Loss: {} | Validation RMSE: {}'.format(batch+1,int((counter+100)/44000),5,running_loss,round(val_rmse,4) ))
            running_loss=0
            if(val_rmse<val_benchmark):
                print ('%---Saving the model---%')
                torch.save({
                    'step':counter+1,
                    'autorec_state_dict': autorec.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'batch':batch,
                    'val_loss':vl,
                    'training_loss':tl
                   },'model_autorec_DRF.pth')
                val_benchmark=val_rmse
        counter=counter+100
# Out:
# Batch: 39 | Step: 1/5 | Training Loss: 6260.594717979431 | Validation RMSE: 0.9356
# %---Saving the model---%
# Batch: 39 | Step: 2/5 | Training Loss: 6258.9457149505615 | Validation RMSE: 0.9369
# Batch: 39 | Step: 3/5 | Training Loss: 6045.901337623596 | Validation RMSE: 0.937
# Batch: 39 | Step: 4/5 | Training Loss: 6400.710886001587 | Validation RMSE: 0.9368
# Batch: 39 | Step: 5/5 | Training Loss: 6376.781566619873 | Validation RMSE: 0.9315
# %---Saving the model---%
# Batch: 40 | Step: 1/5 | Training Loss: 5800.9616355896 | Validation RMSE: 0.9337
# Batch: 40 | Step: 2/5 | Training Loss: 5733.624027252197 | Validation RMSE: 0.9352
# Batch: 40 | Step: 3/5 | Training Loss: 5571.05485534668 | Validation RMSE: 0.9389
# Batch: 40 | Step: 4/5 | Training Loss: 5655.099016666412 | Validation RMSE: 0.9345
# Batch: 40 | Step: 5/5 | Training Loss: 6271.239443778992 | Validation RMSE: 0.9366
# Batch: 41 | Step: 1/5 | Training Loss: 490700.85137939453 | Validation RMSE: 0.9982
# %---Saving the model---%
# Batch: 41 | Step: 2/5 | Training Loss: 300973.46490478516 | Validation RMSE: 0.9811
# %---Saving the model---%
# Batch: 41 | Step: 3/5 | Training Loss: 264020.48571777344 | Validation RMSE: 0.9854
# %---Saving the model---%
# Batch: 41 | Step: 4/5 | Training Loss: 259738.20635986328 | Validation RMSE: 0.9629
# %---Saving the model---%
# Batch: 41 | Step: 5/5 | Training Loss: 257660.60287475586 | Validation RMSE: 0.9508
# %---Saving the model---%
# Batch: 42 | Step: 1/5 | Training Loss: 299471.39904785156 | Validation RMSE: 0.9513
# Batch: 42 | Step: 2/5 | Training Loss: 291636.2449951172 | Validation RMSE: 0.9527
# Batch: 42 | Step: 3/5 | Training Loss: 285681.56268310547 | Validation RMSE: 0.9709
# Batch: 42 | Step: 4/5 | Training Loss: 281766.92694091797 | Validation RMSE: 0.9449
# %---Saving the model---%
# Batch: 42 | Step: 5/5 | Training Loss: 281995.9188232422 | Validation RMSE: 0.9478
# Batch: 43 | Step: 1/5 | Training Loss: 284448.35845947266 | Validation RMSE: 0.9426
# %---Saving the model---%
# Batch: 43 | Step: 2/5 | Training Loss: 276906.6334838867 | Validation RMSE: 0.9513
# Batch: 43 | Step: 3/5 | Training Loss: 260311.14276123047 | Validation RMSE: 0.9366
# %---Saving the model---%
# Batch: 43 | Step: 4/5 | Training Loss: 420172.33630371094 | Validation RMSE: 0.9571
# Batch: 43 | Step: 5/5 | Training Loss: 376346.18927001953 | Validation RMSE: 0.9469
# Batch: 44 | Step: 1/5 | Training Loss: 381457.83923339844 | Validation RMSE: 0.9426
# Batch: 44 | Step: 2/5 | Training Loss: 374142.09899902344 | Validation RMSE: 0.941
# Batch: 44 | Step: 3/5 | Training Loss: 367216.5329589844 | Validation RMSE: 0.9364
# %---Saving the model---%
# Batch: 44 | Step: 4/5 | Training Loss: 370605.79901123047 | Validation RMSE: 0.9486
# Batch: 44 | Step: 5/5 | Training Loss: 371356.4354248047 | Validation RMSE: 0.9525
# Batch: 45 | Step: 1/5 | Training Loss: 391315.37908935547 | Validation RMSE: 0.9535
# Batch: 45 | Step: 2/5 | Training Loss: 369651.47479248047 | Validation RMSE: 0.9661
# Batch: 45 | Step: 3/5 | Training Loss: 366045.14904785156 | Validation RMSE: 0.959
# Batch: 45 | Step: 4/5 | Training Loss: 384014.6137084961 | Validation RMSE: 0.9702
# Batch: 45 | Step: 5/5 | Training Loss: 363071.7894897461 | Validation RMSE: 0.9713
# Batch: 46 | Step: 1/5 | Training Loss: 367296.9351196289 | Validation RMSE: 0.952
# Batch: 46 | Step: 2/5 | Training Loss: 362652.5307006836 | Validation RMSE: 0.966
# Batch: 59 | Step: 5/5 | Training Loss: 347311.3933105469 | Validation RMSE: 0.9694
# Batch: 60 | Step: 1/5 | Training Loss: 351252.9288330078 | Validation RMSE: 0.9656
# Batch: 60 | Step: 2/5 | Training Loss: 347121.66015625 | Validation RMSE: 0.9776
# Batch: 60 | Step: 3/5 | Training Loss: 345190.2585449219 | Validation RMSE: 0.959
# Batch: 60 | Step: 4/5 | Training Loss: 345171.40490722656 | Validation RMSE: 0.9595
# Batch: 60 | Step: 5/5 | Training Loss: 346602.39642333984 | Validation RMSE: 0.9831
# Batch: 61 | Step: 1/5 | Training Loss: 349018.5667114258 | Validation RMSE: 0.9562
# Batch: 61 | Step: 2/5 | Training Loss: 347422.10467529297 | Validation RMSE: 0.9692
# Batch: 61 | Step: 3/5 | Training Loss: 345150.20361328125 | Validation RMSE: 0.9576
# Batch: 61 | Step: 4/5 | Training Loss: 345874.93395996094 | Validation RMSE: 0.9689
# Batch: 61 | Step: 5/5 | Training Loss: 346289.3818359375 | Validation RMSE: 0.9829
# Batch: 62 | Step: 1/5 | Training Loss: 349001.9837036133 | Validation RMSE: 0.9717
# Batch: 62 | Step: 2/5 | Training Loss: 345651.3825073242 | Validation RMSE: 0.9624
# Batch: 62 | Step: 3/5 | Training Loss: 344717.9583129883 | Validation RMSE: 0.9618
# Batch: 62 | Step: 4/5 | Training Loss: 345199.0205078125 | Validation RMSE: 0.98
# Batch: 62 | Step: 5/5 | Training Loss: 344600.4867553711 | Validation RMSE: 0.9973
# Batch: 63 | Step: 1/5 | Training Loss: 347139.3284301758 | Validation RMSE: 0.9768
# Batch: 63 | Step: 2/5 | Training Loss: 345643.36114501953 | Validation RMSE: 0.9654
# Batch: 63 | Step: 3/5 | Training Loss: 343466.13024902344 | Validation RMSE: 0.9588
# Batch: 63 | Step: 4/5 | Training Loss: 345473.93084716797 | Validation RMSE: 0.9629
# Batch: 63 | Step: 5/5 | Training Loss: 343772.4958496094 | Validation RMSE: 0.9946
# Batch: 64 | Step: 1/5 | Training Loss: 346579.07373046875 | Validation RMSE: 0.9615
# Batch: 64 | Step: 2/5 | Training Loss: 343682.298828125 | Validation RMSE: 0.9653
# Batch: 64 | Step: 3/5 | Training Loss: 343390.4174194336 | Validation RMSE: 0.9642
# Batch: 64 | Step: 4/5 | Training Loss: 345652.07873535156 | Validation RMSE: 0.9624
# Batch: 64 | Step: 5/5 | Training Loss: 344352.12774658203 | Validation RMSE: 0.9705
# Batch: 65 | Step: 1/5 | Training Loss: 346675.67028808594 | Validation RMSE: 0.9617
# Batch: 65 | Step: 2/5 | Training Loss: 343855.6559448242 | Validation RMSE: 0.965
# Batch: 65 | Step: 3/5 | Training Loss: 342453.9039916992 | Validation RMSE: 0.9674
# Batch: 65 | Step: 4/5 | Training Loss: 343993.4416503906 | Validation RMSE: 0.9714
# Batch: 65 | Step: 5/5 | Training Loss: 344359.3129272461 | Validation RMSE: 0.9686
# Batch: 66 | Step: 1/5 | Training Loss: 347586.3607788086 | Validation RMSE: 0.9721
# Batch: 66 | Step: 2/5 | Training Loss: 343636.79846191406 | Validation RMSE: 0.9706
# Batch: 79 | Step: 5/5 | Training Loss: 339881.6262817383 | Validation RMSE: 1.0013
# Batch: 80 | Step: 1/5 | Training Loss: 343071.06689453125 | Validation RMSE: 1.0082
# Batch: 80 | Step: 2/5 | Training Loss: 341794.0008544922 | Validation RMSE: 0.9916
# Batch: 80 | Step: 3/5 | Training Loss: 341652.6818847656 | Validation RMSE: 0.9703
# Batch: 80 | Step: 4/5 | Training Loss: 339942.0567626953 | Validation RMSE: 0.9771
# Batch: 80 | Step: 5/5 | Training Loss: 340638.30822753906 | Validation RMSE: 1.0045
# Batch: 81 | Step: 1/5 | Training Loss: 342645.80529785156 | Validation RMSE: 0.9862
# Batch: 81 | Step: 2/5 | Training Loss: 341714.43145751953 | Validation RMSE: 0.9831
# Batch: 81 | Step: 3/5 | Training Loss: 340224.4454345703 | Validation RMSE: 0.976
# Batch: 81 | Step: 4/5 | Training Loss: 339560.4694824219 | Validation RMSE: 0.9782
# Batch: 81 | Step: 5/5 | Training Loss: 340740.5961303711 | Validation RMSE: 0.9973
# Batch: 82 | Step: 1/5 | Training Loss: 342390.17877197266 | Validation RMSE: 0.9807
# Batch: 82 | Step: 2/5 | Training Loss: 341759.3977050781 | Validation RMSE: 0.9795
# Batch: 82 | Step: 3/5 | Training Loss: 340112.5885620117 | Validation RMSE: 0.9717
# Batch: 82 | Step: 4/5 | Training Loss: 340707.6346435547 | Validation RMSE: 0.9803
# Batch: 82 | Step: 5/5 | Training Loss: 340632.4280395508 | Validation RMSE: 0.9774
# Batch: 83 | Step: 1/5 | Training Loss: 342451.1364135742 | Validation RMSE: 0.9791
# Batch: 83 | Step: 2/5 | Training Loss: 341128.80322265625 | Validation RMSE: 0.9797
# Batch: 83 | Step: 3/5 | Training Loss: 340212.61560058594 | Validation RMSE: 0.9761
# Batch: 83 | Step: 4/5 | Training Loss: 342931.87994384766 | Validation RMSE: 0.9844
# Batch: 83 | Step: 5/5 | Training Loss: 341214.93048095703 | Validation RMSE: 0.9776
# Batch: 84 | Step: 1/5 | Training Loss: 342778.6396484375 | Validation RMSE: 0.9779
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-3efad59fa0db> in <module>
#      29
#      30         if (counter+100)%44000==0:
# ---> 31             val_rmse=validation(input_users_val, autorec)
#      32             vl.append(val_rmse)
#      33             print ('Batch: {} | Step: {}/{} | Training Loss: {} | Validation RMSE: {}'.format(batch+1,int((counter+100)/44000),5,running_loss,round(val_rmse,4) ))
#
# <ipython-input-6-500b95b4a3b0> in validation(input_ratings, autorec)
#       7         loss=0
#       8         for i in range(output_ratings.size(0)):
# ----> 9             indices=torch.nonzero(mask[i])
#      10             l=0
#      11             for idx in indices:
#
# KeyboardInterrupt:

# %%
#test_mask=test_df.copy()
#test_mask[~test_mask.isnull()] = 1  # not nan
#test_mask[test_mask.isnull()] = 0   # nan
test_df[test_df.isnull()] = 0   # nan

# %%
input_users_test=torch.from_numpy(test_df.values).to(device).detach()
#mask_test=torch.from_numpy(test_mask.values).to(device).detach()
#print ('RMSE: {}, Precision@10: {}'.format(validation(input_users_test, mask_test, autorec)))

# %%
rmse=validation(input_users_test, autorec)
print ('RMSE: {}'.format(rmse))
# Out:
# RMSE: 0.9381546974182129
